# %% [markdown]
# # READING DATA

# %%
import pandas as pd
import numpy as np
iris = pd.read_csv("iris.csv")

# %% [markdown]
# # DATAFRAMES

# %%
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df = iris.copy()
df.shape
# Out:
# (149, 5)

# %%
# The total records were down to 149 as the headers were record itself.
# AS we dont wanna set the record as the header,we have to set (header = None)
iris = pd.read_csv("iris.csv",header = None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
df = iris.copy()
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4     object
# dtype: object

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
# Assigning variable names for the columns
df.columns = ['Sepal_length','Sepal_width','Petal_length','Petal_width','Flower_type']
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width     Flower_type
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width',
#        'Flower_type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sepal_length    float64
# Sepal_width     float64
# Petal_length    float64
# Petal_width     float64
# Flower_type      object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        Sepal_length  Sepal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_length  150 non-null    float64
#  1   Sepal_width   150 non-null    float64
#  2   Petal_length  150 non-null    float64
#  3   Petal_width   150 non-null    float64
#  4   Flower_type   150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.groupby("Flower_type").agg([np.mean,np.median])
# Out:
#                 Sepal_length        Sepal_width        Petal_length         \
#                         mean median        mean median         mean median
# Flower_type
# Iris-setosa            5.006    5.0       3.418    3.4        1.464   1.50
# Iris-versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# Iris-virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#                 Petal_width
#                        mean median
# Flower_type
# Iris-setosa           0.244    0.2
# Iris-versicolor       1.326    1.3
# Iris-virginica        2.026    2.0

# %% [markdown]
# # DATA ANALYSIS

# %%
#Plotting a histogram beteween the frequency of data and size of data
import seaborn as sns
a = df.plot.hist(bins= 20,alpha = 0.5)
a.set_xlabel('size')
# Out:
# Text(0.5, 0, 'size')

# %%
#pairwise relationships in a dataset
sns.pairplot(df,hue="Flower_type")

# %%
#rectangular data as a color-encoded matrix
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(),annot = True)
plt.show()
# Out:
# <ipython-input-25-054883a14dd2>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)

# %% [markdown]
# # SPLITTING DATA INTO TRAIN AND TEST SETS

# %%
#To encode target labels with value between 0 and n-1 classes
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
df["Flower_type"] = l.fit_transform(df['Flower_type'])
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width  Flower_type
# 0             5.1          3.5           1.4          0.2            0
# 1             4.9          3.0           1.4          0.2            0
# 2             4.7          3.2           1.3          0.2            0
# 3             4.6          3.1           1.5          0.2            0
# 4             5.0          3.6           1.4          0.2            0
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3            2
# 146           6.3          2.5           5.0          1.9            2
# 147           6.5          3.0           5.2          2.0            2
# 148           6.2          3.4           5.4          2.3            2
# 149           5.9          3.0           5.1          1.8            2
#
# [150 rows x 5 columns]

# %% [markdown]
# # TRAINING THE MODEL USING LINEAR VECTOR SUPPORT CLASSIFICATION

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ["Flower_type"])
Y = df["Flower_type"]
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.3)
X,Y
# Out:
# (     Sepal_length  Sepal_width  Petal_length  Petal_width
#  0             5.1          3.5           1.4          0.2
#  1             4.9          3.0           1.4          0.2
#  2             4.7          3.2           1.3          0.2
#  3             4.6          3.1           1.5          0.2
#  4             5.0          3.6           1.4          0.2
#  ..            ...          ...           ...          ...
#  145           6.7          3.0           5.2          2.3
#  146           6.3          2.5           5.0          1.9
#  147           6.5          3.0           5.2          2.0
#  148           6.2          3.4           5.4          2.3
#  149           5.9          3.0           5.1          1.8
#
#  [150 rows x 4 columns],
#  0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  145    2
#  146    2
#  147    2
#  148    2
#  149    2
#  Name: Flower_type, Length: 150, dtype: int64)

# %%
from sklearn.svm import SVC
Li_svc = SVC(kernel='linear',C=1.0)
Li_svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=Li_svc.predict(x_test)
y_pred
# Out:
# array([0, 1, 2, 1, 2, 1, 1, 0, 0, 1, 2, 1, 0, 0, 2, 2, 2, 2, 0, 2, 0, 1,
#        2, 0, 2, 1, 0, 2, 1, 0, 2, 0, 2, 1, 2, 1, 2, 1, 2, 0, 1, 0, 0, 0,
#        2])

# %%
##Predicting  on the train models
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score = accuracy_score(y_test,y_pred)
print("Linear Support vector classificaion")
classification_report(y_test,y_pred)
print(f'Accuracy: {round(score*100,6)}%')
# Out:
# Linear Support vector classificaion
# Accuracy: 95.555556%
